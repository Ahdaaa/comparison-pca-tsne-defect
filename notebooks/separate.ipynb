# %% [markdown]
# ##### Analyse Cleaned Datasets

# %%
import sys
sys.path.append("..")  # go back one folder

from main import run_summary

df = run_summary()
# Out:
# Dataset  Jumlah Atribut  Jumlah Instance  Jumlah Defective  Jumlah Tidak Defective Nama File
#     CM1              37              327                42                     285  CM1.arff
#     JM1              21             7720              1612                    6108  JM1.arff
#     KC1              21             1162               294                     868  KC1.arff
#     KC3              39              194                36                     158  KC3.arff
#     KC4               0                0                 0                       0  KC4.arff
#     MC1              38             1952                36                    1916  MC1.arff
#     MC2              39              124                44                      80  MC2.arff
#     MW1              37              250                25                     225  MW1.arff
#     PC1              37              679                55                     624  PC1.arff
#     PC2              36              722                16                     706  PC2.arff
#     PC3              37             1053               130                     923  PC3.arff
#     PC4              37             1270               176                    1094  PC4.arff
#     PC5              38             1694               458                    1236  PC5.arff

# %% [markdown]
# ##### Load Single Dataset

# %%
from main import load_single

dataset_name = "MC2"
lowercase_dataset = dataset_name.lower()

merged = load_single(f"{dataset_name}.arff")
merged.head()
# Out:
# (124, 40)
#    loc_blank  branch_count  call_pairs  loc_code_and_comment  loc_comments  \
# 0        5.0          15.0         0.0                   0.0           5.0
# 1        6.0           7.0         0.0                   0.0           6.0
# 2        1.0          19.0         1.0                   0.0           0.0
# 3        9.0           3.0         2.0                   0.0           6.0
# 4        6.0           3.0         1.0                   0.0           7.0
#
#    condition_count  cyclomatic_complexity  cyclomatic_density  decision_count  \
# 0             26.0                    8.0                0.20            12.0
# 1             12.0                    4.0                0.27             6.0
# 2             36.0                   10.0                0.23            18.0
# 3              4.0                    2.0                0.07             2.0
# 4              4.0                    2.0                0.15             2.0
#
#    decision_density  ...  node_count  normalized_cylomatic_complexity  \
# 0              2.17  ...        19.0                             0.15
# 1              2.00  ...        12.0                             0.14
# 2              2.00  ...        32.0                             0.22
# 3              2.00  ...         9.0                             0.04
# 4              2.00  ...         8.0                             0.07
#
#    num_operands  num_operators  num_unique_operands  num_unique_operators  \
# 0          79.0          125.0                 12.0                  20.0
# 1          19.0           39.0                 13.0                  16.0
# 2          83.0          119.0                 28.0                  18.0
# 3          54.0           61.0                 28.0                  11.0
# 4          29.0           43.0                 11.0                  16.0
#
#    number_of_lines  percent_comments  loc_total  defective
# 0             53.0             10.87       41.0          0
# 1             29.0             28.57       15.0          1
# 2             46.0              0.00       43.0          0
# 3             47.0             16.67       30.0          1
# 4             28.0             35.00       13.0          1
#
# [5 rows x 40 columns]

# %% [markdown]
# ##### Exploratory Data Analysis (EDA)

# %% [markdown]
# Number of Instance dan Label Distribution

# %%
print("Jumlah total instance:", len(merged))
print("\nDistribusi label 'defective':")
print(merged['defective'].value_counts())
print("\nProporsi:")
print(merged['defective'].value_counts(normalize=True))
# Out:
# Jumlah total instance: 124
#
# Distribusi label 'defective':
# defective
# 0    80
# 1    44
# Name: count, dtype: int64
#
# Proporsi:
# defective
# 0    0.645161
# 1    0.354839
# Name: proportion, dtype: float64

# %% [markdown]
# Describe Feature Statistic

# %%
merged.describe()
# Out:
#        loc_blank  branch_count  call_pairs  loc_code_and_comment  \
# count  124.00000    124.000000  124.000000            124.000000
# mean    11.33871     16.556452    2.266129              2.403226
# std     16.29848     21.781361    3.253788              4.527997
# min      0.00000      3.000000    0.000000              0.000000
# 25%      1.75000      5.000000    0.000000              0.000000
# 50%      6.00000      9.000000    1.000000              0.000000
# 75%     13.25000     19.000000    3.000000              3.000000
# max    105.00000    125.000000   18.000000             19.000000
#
#        loc_comments  condition_count  cyclomatic_complexity  \
# count    124.000000       124.000000             124.000000
# mean      13.887097        27.580645               8.967742
# std       21.349286        37.524430              11.045314
# min        0.000000         4.000000               2.000000
# 25%        1.000000         7.500000               3.000000
# 50%        6.000000        16.000000               5.000000
# 75%       17.000000        30.000000              10.000000
# max      123.000000       216.000000              63.000000
#
#        cyclomatic_density  decision_count  decision_density  ...  node_count  \
# count          124.000000      124.000000        124.000000  ...  124.000000
# mean             0.254597       12.564516          2.100323  ...   28.451613
# std              0.151252       16.209122          0.199389  ...   33.208715
# min              0.040000        2.000000          2.000000  ...    5.000000
# 25%              0.170000        3.500000          2.000000  ...    9.000000
# 50%              0.220000        8.000000          2.000000  ...   18.000000
# 75%              0.290000       14.000000          2.132500  ...   31.250000
# max              1.000000      102.000000          3.000000  ...  191.000000
#
#        normalized_cylomatic_complexity  num_operands  num_operators  \
# count                       124.000000    124.000000     124.000000
# mean                          0.159677     87.491935     119.129032
# std                           0.094456    104.642286     147.592273
# min                           0.030000      1.000000       3.000000
# 25%                           0.100000     20.750000      27.750000
# 50%                           0.140000     50.000000      66.500000
# 75%                           0.190000    120.750000     158.000000
# max                           0.500000    615.000000     864.000000
#
#        num_unique_operands  num_unique_operators  number_of_lines  \
# count           124.000000            124.000000       124.000000
# mean             24.129032             15.709677        71.991935
# std              20.965309              6.541642        86.564276
# min               1.000000              3.000000         4.000000
# 25%              10.000000             11.000000        17.000000
# 50%              17.500000             15.500000        42.000000
# 75%              33.250000             20.000000        86.000000
# max              98.000000             32.000000       474.000000
#
#        percent_comments   loc_total   defective
# count        124.000000  124.000000  124.000000
# mean          21.523226   44.290323    0.354839
# std           15.340127   52.754035    0.480405
# min            0.000000    2.000000    0.000000
# 25%            8.900000   12.000000    0.000000
# 50%           22.830000   27.500000    0.000000
# 75%           30.655000   57.000000    1.000000
# max           70.000000  306.000000    1.000000
#
# [8 rows x 40 columns]

# %% [markdown]
# Feature Correlation Heatmap

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(16, 12))
sns.heatmap(merged.drop(columns=["defective"]).corr(), cmap="coolwarm", annot=False)
plt.title("Korelasi antar Fitur")
plt.show()

# %% [markdown]
# Feature Correlation to Defective Label

# %%
label_corr = merged.corr()["defective"].drop("defective").sort_values(ascending=False)
label_corr.plot(kind="barh", figsize=(10, 8), title="Korelasi Fitur terhadap Label Defective")
plt.xlabel("Nilai Korelasi")
plt.show()

# %% [markdown]
# ##### Oversampling

# %% [markdown]
# Imports

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Separate Feature and Defective Label

# %%
X = merged.drop(columns=["defective"])
y = merged["defective"]

# %% [markdown]
# Oversampling with SMOTE

# %%
smote = SMOTE(random_state=42)
X_resampled, y_resampled = smote.fit_resample(X, y)

# %%
print("Sebelum Oversampling:")
print(y.value_counts())

print("\nSetelah Oversampling:")
print(pd.Series(y_resampled).value_counts())
# Out:
# Sebelum Oversampling:
# defective
# 0    80
# 1    44
# Name: count, dtype: int64
#
# Setelah Oversampling:
# defective
# 0    80
# 1    80
# Name: count, dtype: int64

# %% [markdown]
# Visualization

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 5))

sns.countplot(x=y, ax=ax[0])
ax[0].set_title("Distribusi Label Sebelum Oversampling")

sns.countplot(x=y_resampled, ax=ax[1])
ax[1].set_title("Distribusi Label Setelah Oversampling")

plt.tight_layout()
plt.show()

# %% [markdown]
# Store the Results

# %%
df_resampled = pd.DataFrame(X_resampled, columns=X.columns)
df_resampled["defective"] = y_resampled

# %% [markdown]
# ##### Normalization

# %% [markdown]
# Normalization with Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_resampled.drop(columns=['defective']))

# Simpan label
y_scaled = df_resampled['defective']

# %%
# Konversi kembali ke DataFrame
X_scaled_df = pd.DataFrame(X_scaled, columns=df_resampled.drop(columns=['defective']).columns)

# Tampilkan beberapa baris pertama
X_scaled_df.head()
# Out:
#    loc_blank  branch_count  call_pairs  loc_code_and_comment  loc_comments  \
# 0  -0.458552     -0.202355   -0.776764             -0.567076     -0.485660
# 1  -0.403460     -0.516364   -0.776764             -0.567076     -0.444352
# 2  -0.678920     -0.045351   -0.467220             -0.567076     -0.692199
# 3  -0.238184     -0.673368   -0.157677             -0.567076     -0.444352
# 4  -0.403460     -0.673368   -0.467220             -0.567076     -0.403045
#
#    condition_count  cyclomatic_complexity  cyclomatic_density  decision_count  \
# 0        -0.177061              -0.216435           -0.389994       -0.170238
# 1        -0.496409              -0.527778            0.113277       -0.491164
# 2         0.051044              -0.060763           -0.174307        0.150688
# 3        -0.678893              -0.683450           -1.324642       -0.705114
# 4        -0.678893              -0.683450           -0.749474       -0.705114
#
#    decision_density  ...  multiple_condition_count  node_count  \
# 0          0.311310  ...                 -0.178237   -0.384708
# 1         -0.576276  ...                 -0.496088   -0.567341
# 2         -0.576276  ...                  0.048799   -0.045532
# 3         -0.576276  ...                 -0.677718   -0.645613
# 4         -0.576276  ...                 -0.677718   -0.671703
#
#    normalized_cylomatic_complexity  num_operands  num_operators  \
# 0                        -0.096754     -0.187236      -0.086889
# 1                        -0.212299     -0.698253      -0.591430
# 2                         0.712062     -0.153168      -0.122089
# 3                        -1.367751     -0.400160      -0.462361
# 4                        -1.021115     -0.613083      -0.567963
#
#    num_unique_operands  num_unique_operators  number_of_lines  \
# 0            -0.641908              0.485059        -0.317619
# 1            -0.596334             -0.099746        -0.558946
# 2             0.087286              0.192656        -0.388006
# 3             0.087286             -0.830752        -0.377951
# 4            -0.687483             -0.099746        -0.569001
#
#    percent_comments  loc_total
# 0         -0.756580  -0.181200
# 1          0.463228  -0.608225
# 2         -1.505693  -0.148352
# 3         -0.356869  -0.361864
# 4          0.906355  -0.641073
#
# [5 rows x 39 columns]

# %% [markdown]
# ##### PCA

# %% [markdown]
# PCA with Maximum Component

# %%
from sklearn.decomposition import PCA

# Jumlah maksimum komponen = jumlah fitur
pca = PCA(n_components=X_scaled.shape[1])
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# Cumulative Explained Variance

# %%
import numpy as np
import matplotlib.pyplot as plt

explained_variance = np.cumsum(pca.explained_variance_ratio_)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(explained_variance) + 1), explained_variance, marker='o')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% Variance Threshold')
plt.title('Cumulative Explained Variance (CEV)')
plt.xlabel('Jumlah Komponen')
plt.ylabel('Cumulative Explained Variance')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Variance Comparison

# %%
pca_variance_df = pd.DataFrame({
    'Komponen ke-': [f'PC{i+1}' for i in range(len(pca.explained_variance_ratio_))],
    'Explained Variance Ratio': pca.explained_variance_ratio_,
    'Cumulative Variance': explained_variance
})

pca_variance_df.head(10)  # Atau print semua
# Out:
#   Komponen ke-  Explained Variance Ratio  Cumulative Variance
# 0          PC1                  0.657530             0.657530
# 1          PC2                  0.079740             0.737270
# 2          PC3                  0.048032             0.785301
# 3          PC4                  0.039531             0.824832
# 4          PC5                  0.032448             0.857280
# 5          PC6                  0.028198             0.885479
# 6          PC7                  0.021271             0.906750
# 7          PC8                  0.020633             0.927383
# 8          PC9                  0.016676             0.944059
# 9         PC10                  0.011654             0.955714

# %% [markdown]
# Chosen N Component

# %%
thresholds = [0.95, 0.96, 0.97, 0.98, 0.99, 1.00]
epsilon = 1e-8

n_components_list = []

for threshold in thresholds:
    idx = np.argmax(explained_variance >= (threshold - epsilon))
    n_components = idx + 1
    n_components_list.append((threshold, n_components))

# Tampilkan hasilnya
for threshold, n in n_components_list:
    print(f"Untuk threshold {threshold*100:.0f}%, jumlah komponen: {n}")
# Out:
# Untuk threshold 95%, jumlah komponen: 10
# Untuk threshold 96%, jumlah komponen: 11
# Untuk threshold 97%, jumlah komponen: 12
# Untuk threshold 98%, jumlah komponen: 14
# Untuk threshold 99%, jumlah komponen: 16
# Untuk threshold 100%, jumlah komponen: 34

# %% [markdown]
# 10 Components for Classification Later

# %%
# from sklearn.model_selection import train_test_split
# from sklearn.decomposition import PCA

# # Split dulu
# X_train_raw, X_test_raw, y_train, y_test = train_test_split(
#     X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
# )

# # Fit PCA hanya di training
# pca = PCA(n_components=8)
# X_train_pca = pca.fit_transform(X_train_raw)

# # Transform testing pakai PCA dari training
# X_test_pca = pca.transform(X_test_raw)

# %% [markdown]
# PC1 and PC2 Visualization

# %%
import matplotlib.pyplot as plt

# Ambil hanya dua komponen pertama dari PCA
pca_2d = PCA(n_components=2)
X_pca_2d = pca_2d.fit_transform(X_scaled)

# Buat DataFrame untuk visualisasi
pca_2d_df = pd.DataFrame(data=X_pca_2d, columns=["PC1", "PC2"])
pca_2d_df["defective"] = y_scaled.values

# Scatter plot
plt.figure(figsize=(8, 6))
colors = {0: 'skyblue', 1: 'salmon'}

for label in [0, 1]:
    subset = pca_2d_df[pca_2d_df["defective"] == label]
    plt.scatter(subset["PC1"], subset["PC2"], 
                label=f"Defective = {label}", 
                alpha=0.6, c=colors[label])

plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Visualisasi PCA 2D berdasarkan label defective")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### t-SNE

# %% [markdown]
# t-SNE

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.metrics import silhouette_score, davies_bouldin_score
from parametric_tSNE import Parametric_tSNE


# Daftar nilai perplexity yang ingin diuji
perplexities = [5, 10, 30, 50]

plt.figure(figsize=(18, 12))

# Simpan hasil coherence metrics
coherence_results = []

for i, perplexity in enumerate(perplexities, 1):
    print(f"\n▶️ Perplexity = {perplexity}")
    
    # 1️⃣ Fit parametric t-SNE ke seluruh data
    ptSNE = Parametric_tSNE(X_scaled.shape[1], 2, perplexity, seed=42)
    ptSNE.fit(X_scaled)
    
    # 2️⃣ Transform data ke ruang embedding
    X_tsne = ptSNE.transform(X_scaled)

    # 3️⃣ Buat DataFrame untuk visualisasi
    tsne_df = pd.DataFrame(X_tsne, columns=["TSNE1", "TSNE2"])
    tsne_df["defective"] = y_scaled.values

    # 4️⃣ Plot
    plt.subplot(2, 2, i)
    for label in [0, 1]:
        subset = tsne_df[tsne_df["defective"] == label]
        plt.scatter(subset["TSNE1"], subset["TSNE2"], alpha=0.6, label=f"Defective = {label}")
    
    plt.title(f"Parametric t-SNE (Perplexity={perplexity})")
    plt.xlabel("TSNE1")
    plt.ylabel("TSNE2")
    plt.legend()
    plt.grid(True)
    
    # 5️⃣ Coherence evaluation: silhouette dan Davies-Bouldin
    silhouette = silhouette_score(X_tsne, y_scaled)
    db_index = davies_bouldin_score(X_tsne, y_scaled)
    
    print(f"  Silhouette Score : {silhouette:.4f}")
    print(f"  Davies-Bouldin Index : {db_index:.4f}")
    
    coherence_results.append({
        "Perplexity": perplexity,
        "Silhouette": silhouette,
        "Davies-Bouldin": db_index
    })

plt.tight_layout()
plt.show()
# Out:
# ▶️ Perplexity = 5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
#   Silhouette Score : 0.0842
#   Davies-Bouldin Index : 2.3684
#
# ▶️ Perplexity = 10
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#   Silhouette Score : 0.0835
#   Davies-Bouldin Index : 2.2802
#
# ▶️ Perplexity = 30
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#   Silhouette Score : 0.0830
#   Davies-Bouldin Index : 2.1554
#
# ▶️ Perplexity = 50
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
#   Silhouette Score : 0.0810
#   Davies-Bouldin Index : 2.1042

# %% [markdown]
# Copy to clipboard

# %%
# Buat DataFrame dari hasil evaluasi
df_coherence = pd.DataFrame(coherence_results)

# Tampilkan
print("\n✅ Hasil Evaluasi Coherence untuk Tiap Perplexity:")
print(df_coherence.to_string(index=False))

df_coherence["Silhouette"] = df_coherence["Silhouette"].apply(lambda x: f"{x:.4f}".replace(".", ","))
df_coherence["Davies-Bouldin"] = df_coherence["Davies-Bouldin"].apply(lambda x: f"{x:.4f}".replace(".", ","))

# Salin ke clipboard untuk Excel (tanpa index, tab-sep)
df_coherence.to_clipboard(index=False, sep='\t')
# Out:
# ✅ Hasil Evaluasi Coherence untuk Tiap Perplexity:
#  Perplexity  Silhouette  Davies-Bouldin
#           5    0.084184        2.368426
#          10    0.083482        2.280184
#          30    0.083050        2.155392
#          50    0.080965        2.104193

# %% [markdown]
# ##### PCA + Classification

# %% [markdown]
# Single Learning and Ensemble Learning Imports

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

from catboost import CatBoostClassifier
from xgboost import XGBClassifier

# %% [markdown]
# Model Train and Evaluation

# %%
# 1️⃣ Split data
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
)

# 2️⃣ Daftar nilai n_components dari PCA (misal dari threshold CEV 95%–100%)
n_components_list = [10] # coba 1 aja buat sebelum hyperparameter tuning

# 3️⃣ Model-model klasifikasi
models = { 
    "Logistic Regression": LogisticRegression(solver='saga', max_iter=1000, random_state=42),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", random_state=42)
}

results = []

# 4️⃣ Loop untuk setiap n_components
for n_comp in n_components_list:
    print(f"\n▶️ PCA: n_components={n_comp}")

    # Fit PCA di data train
    pca = PCA(n_components=n_comp)
    X_train_pca = pca.fit_transform(X_train_raw)
    X_test_pca = pca.transform(X_test_raw)

    for name, model in models.items():
        model.fit(X_train_pca, y_train)
        y_pred = model.predict(X_test_pca)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results.append({
            "n_components": n_comp,
            "Model": name,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"  {name}: acc={acc:.4f}, f1={f1:.4f}")

# 5️⃣ Simpan hasil ke DataFrame
df_results_pca = pd.DataFrame(results)
df_results_pca_sorted = df_results_pca.sort_values(by=["n_components", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Evaluasi PCA:")
print(df_results_pca_sorted.to_string(index=False))
# Out:
# ▶️ PCA: n_components=10
#   Logistic Regression: acc=0.5938, f1=0.6286
#   SVM: acc=0.6875, f1=0.7059
#   KNN: acc=0.6875, f1=0.7222
#   Random Forest: acc=0.8125, f1=0.8333
#   AdaBoost: acc=0.5938, f1=0.6061
#   Gradient Boosting: acc=0.6875, f1=0.7368
#   CatBoost: acc=0.6562, f1=0.7317
#   XGBoost: acc=0.7188, f1=0.7692
#
# ✅ Hasil Evaluasi PCA:
#  n_components               Model  Accuracy  Precision  Recall  F1-Score
#            10       Random Forest   0.81250   0.750000  0.9375  0.833333
#            10             XGBoost   0.71875   0.652174  0.9375  0.769231
#            10   Gradient Boosting   0.68750   0.636364  0.8750  0.736842
#            10            CatBoost   0.65625   0.600000  0.9375  0.731707
#            10                 KNN   0.68750   0.650000  0.8125  0.722222
#            10                 SVM   0.68750   0.666667  0.7500  0.705882
#            10 Logistic Regression   0.59375   0.578947  0.6875  0.628571
#            10            AdaBoost   0.59375   0.588235  0.6250  0.606061

# %%
# Tampilkan dalam bentuk DataFrame
df_results = pd.DataFrame(results)

# Urutkan berdasarkan F1-Score tertinggi
df_results_sorted = df_results.sort_values(by="F1-Score", ascending=False)

df_to_copy = df_results_sorted.drop(columns=["n_components"])

# Tampilkan hasil akhir
print("\n✅ Hasil Evaluasi Model:")
print(df_to_copy.to_string(index=False))

df_to_copy.to_clipboard(index=False, excel=True, sep='\t')
# Out:
# ✅ Hasil Evaluasi Model:
#               Model  Accuracy  Precision  Recall  F1-Score
#       Random Forest   0.81250   0.750000  0.9375  0.833333
#             XGBoost   0.71875   0.652174  0.9375  0.769231
#   Gradient Boosting   0.68750   0.636364  0.8750  0.736842
#            CatBoost   0.65625   0.600000  0.9375  0.731707
#                 KNN   0.68750   0.650000  0.8125  0.722222
#                 SVM   0.68750   0.666667  0.7500  0.705882
# Logistic Regression   0.59375   0.578947  0.6875  0.628571
#            AdaBoost   0.59375   0.588235  0.6250  0.606061

# %% [markdown]
# ##### Parametric t-SNE + Classification

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.metrics import classification_report, accuracy_score, precision_score, recall_score, f1_score

from parametric_tSNE import Parametric_tSNE
import pandas as pd

# 1️⃣ Split data
X_train_raw, X_test_raw, y_train, y_test = train_test_split(
    X_scaled, y_scaled, test_size=0.2, stratify=y_scaled, random_state=42
)

# 2️⃣ Kombinasi output_dim yang diambil dari CEV PCA
output_dims = [10] # sebelum hyperparameter tuning, coba satu dulu, abis itu langsung tuning
perplexity = 5

# 3️⃣ Model-model klasifikasi
models = { 
    "Logistic Regression": LogisticRegression(solver='saga', max_iter=1000, random_state=42),
    "SVM": SVC(),
    "KNN": KNeighborsClassifier(),
    "Random Forest": RandomForestClassifier(random_state=42),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "CatBoost": CatBoostClassifier(verbose=0, random_state=42),
    "XGBoost": XGBClassifier(eval_metric="logloss", random_state=42)
}

results = []

# 4️⃣ Loop semua output_dim
for out_dim in output_dims:
    print(f"\n▶️ Parametric t-SNE: output_dim={out_dim}, perplexity={perplexity}")
    
    # Fit t-SNE hanya pada data train
    ptSNE = Parametric_tSNE(X_train_raw.shape[1], out_dim, perplexity, seed=42)
    ptSNE.fit(X_train_raw)
    
    # Transform data
    X_train_tsne = ptSNE.transform(X_train_raw)
    X_test_tsne = ptSNE.transform(X_test_raw)
    
    for name, model in models.items():
        model.fit(X_train_tsne, y_train)
        y_pred = model.predict(X_test_tsne)
        
        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)
        
        results.append({
            "Output Dim": out_dim,
            "Perplexity": perplexity,
            "Model": name,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"  {name}: acc={acc:.4f}, f1={f1:.4f}")

# 5️⃣ Simpan hasil ke DataFrame
df_results = pd.DataFrame(results)
df_results_sorted = df_results.sort_values(by=["Output Dim", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Evaluasi Parametric t-SNE:")
print(df_results_sorted.to_string(index=False))

# Opsional: Simpan ke CSV
# df_results_sorted.to_csv("parametric_tsne_results.csv", index=False)
# Out:
# ▶️ Parametric t-SNE: output_dim=10, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#   Logistic Regression: acc=0.5312, f1=0.4444
#   SVM: acc=0.5312, f1=0.4444
#   KNN: acc=0.5000, f1=0.4667
#   Random Forest: acc=0.6250, f1=0.6250
#   AdaBoost: acc=0.5625, f1=0.5000
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#   Gradient Boosting: acc=0.5625, f1=0.6111
#   CatBoost: acc=0.5625, f1=0.5333
#   XGBoost: acc=0.6562, f1=0.6857
#
# ✅ Hasil Evaluasi Parametric t-SNE:
#  Output Dim  Perplexity               Model  Accuracy  Precision  Recall  F1-Score
#          10           5             XGBoost   0.65625   0.631579  0.7500  0.685714
#          10           5       Random Forest   0.62500   0.625000  0.6250  0.625000
#          10           5   Gradient Boosting   0.56250   0.550000  0.6875  0.611111
#          10           5            CatBoost   0.56250   0.571429  0.5000  0.533333
#          10           5            AdaBoost   0.56250   0.583333  0.4375  0.500000
#          10           5                 KNN   0.50000   0.500000  0.4375  0.466667
#          10           5 Logistic Regression   0.53125   0.545455  0.3750  0.444444
#          10           5                 SVM   0.53125   0.545455  0.3750  0.444444

# %% [markdown]
# Copy to clipboard

# %%
out_dim = 10
df_filtered = df_results_sorted[df_results_sorted["Output Dim"] == out_dim]

# Drop kolom yang tidak perlu disalin
df_to_copy = df_filtered.drop(columns=["Output Dim", "Perplexity"])

# Tampilkan ke terminal
print(df_to_copy.to_string(index=False))

# Salin ke clipboard tanpa kolom tambahan
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
#               Model  Accuracy  Precision  Recall  F1-Score
#             XGBoost   0.65625   0.631579  0.7500  0.685714
#       Random Forest   0.62500   0.625000  0.6250  0.625000
#   Gradient Boosting   0.56250   0.550000  0.6875  0.611111
#            CatBoost   0.56250   0.571429  0.5000  0.533333
#            AdaBoost   0.56250   0.583333  0.4375  0.500000
#                 KNN   0.50000   0.500000  0.4375  0.466667
# Logistic Regression   0.53125   0.545455  0.3750  0.444444
#                 SVM   0.53125   0.545455  0.3750  0.444444

# %% [markdown]
# ##### Hyperparameter Tuning After PCA

# %% [markdown]
# Parameter Grids

# %%
from sklearn.model_selection import GridSearchCV

# Parameter grid untuk setiap model
param_grids = {
    "Logistic Regression": {
        "C": [0.01, 0.1, 1, 10]
    },
    "SVM": {
        "C": [0.1, 1, 10],
        "kernel": ["linear", "rbf"]
    },
    "KNN": {
        "n_neighbors": [3, 5, 7, 9]
    },
    "Random Forest": {
        "n_estimators": [50, 100, 200],
        "max_depth": [None, 5, 10]
    },
    "AdaBoost": {
        "n_estimators": [50, 100, 200],
        "learning_rate": [0.5, 1.0]
    },
    "Gradient Boosting": {
        "n_estimators": [50, 100],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5]
    },
    "CatBoost": {
        "iterations": [100, 200],
        "learning_rate": [0.03, 0.1],
        "depth": [3, 5, 7]
    },
    "XGBoost": {
        "n_estimators": [100, 200],
        "learning_rate": [0.05, 0.1],
        "max_depth": [3, 5, 7]
    }
}

# %% [markdown]
# Lakukan GridsearchCV

# %%
from sklearn.model_selection import StratifiedKFold

# 2️⃣ Daftar n_components dari threshold CEV PCA
n_components_list = [10, 11, 12, 14, 16, 34]

# 3️⃣ Simpan hasil tuning
results_pca_tuned = []

# 4️⃣ Loop semua n_components
for n_comp in n_components_list:
    print(f"\n🎯 PCA n_components={n_comp}")
    
    pca = PCA(n_components=n_comp)
    X_train_pca = pca.fit_transform(X_train_raw)
    X_test_pca = pca.transform(X_test_raw)

    for name, model in models.items():
        print(f"\nTuning {name} (PCA)...")
        grid = GridSearchCV(
            model,
            param_grids[name],
            cv=StratifiedKFold(n_splits=5),
            scoring='f1',
            n_jobs=-1
        )
        grid.fit(X_train_pca, y_train)

        best_model = grid.best_estimator_
        y_pred = best_model.predict(X_test_pca)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results_pca_tuned.append({
            "n_components": n_comp,
            "Model": name,
            "Best Params": grid.best_params_,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"\n==== {name} (PCA + Tuned) ====")
        print("Best Params:", grid.best_params_)
        print(classification_report(y_test, y_pred))

# 5️⃣ Simpan hasil ke DataFrame
df_results_pca_tuned = pd.DataFrame(results_pca_tuned)
df_results_pca_tuned_sorted = df_results_pca_tuned.sort_values(by=["n_components", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Hyperparameter Tuning PCA:")
print(df_results_pca_tuned_sorted.to_string(index=False))
# Out:
# 🎯 PCA n_components=10
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.57      0.50      0.53        16
#            1       0.56      0.62      0.59        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.62      0.81      0.70        16
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.66      0.65        32
# weighted avg       0.67      0.66      0.65        32
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 5}
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.65      0.81      0.72        16
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': 10, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.91      0.62      0.74        16
#            1       0.71      0.94      0.81        16
#
#     accuracy                           0.78        32
#    macro avg       0.81      0.78      0.78        32
# weighted avg       0.81      0.78      0.78        32
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.67        16
#            1       0.67      0.75      0.71        16
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.69      0.56      0.62        16
#            1       0.63      0.75      0.69        16
#
#     accuracy                           0.66        32
#    macro avg       0.66      0.66      0.65        32
# weighted avg       0.66      0.66      0.65        32
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        16
#            1       0.65      0.94      0.77        16
#
#     accuracy                           0.72        32
#    macro avg       0.77      0.72      0.70        32
# weighted avg       0.77      0.72      0.70        32
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62        16
#            1       0.64      0.88      0.74        16
#
#     accuracy                           0.69        32
#    macro avg       0.72      0.69      0.68        32
# weighted avg       0.72      0.69      0.68        32
#
#
# 🎯 PCA n_components=11
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 1}
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55        16
#            1       0.58      0.69      0.63        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.62      0.81      0.70        16
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.66      0.65        32
# weighted avg       0.67      0.66      0.65        32
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46        16
#            1       0.55      0.75      0.63        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.91      0.62      0.74        16
#            1       0.71      0.94      0.81        16
#
#     accuracy                           0.78        32
#    macro avg       0.81      0.78      0.78        32
# weighted avg       0.81      0.78      0.78        32
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55        16
#            1       0.58      0.69      0.63        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.65      0.81      0.72        16
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 100, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67        16
#            1       0.67      0.88      0.76        16
#
#     accuracy                           0.72        32
#    macro avg       0.74      0.72      0.71        32
# weighted avg       0.74      0.72      0.71        32
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.77      0.62      0.69        16
#            1       0.68      0.81      0.74        16
#
#     accuracy                           0.72        32
#    macro avg       0.73      0.72      0.72        32
# weighted avg       0.73      0.72      0.72        32
#
#
# 🎯 PCA n_components=12
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 1}
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55        16
#            1       0.58      0.69      0.63        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.67      0.50      0.57        16
#            1       0.60      0.75      0.67        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46        16
#            1       0.55      0.75      0.63        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        16
#            1       0.65      0.94      0.77        16
#
#     accuracy                           0.72        32
#    macro avg       0.77      0.72      0.70        32
# weighted avg       0.77      0.72      0.70        32
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.60      0.56      0.58        16
#            1       0.59      0.62      0.61        16
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.90      0.56      0.69        16
#            1       0.68      0.94      0.79        16
#
#     accuracy                           0.75        32
#    macro avg       0.79      0.75      0.74        32
# weighted avg       0.79      0.75      0.74        32
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67        16
#            1       0.67      0.88      0.76        16
#
#     accuracy                           0.72        32
#    macro avg       0.74      0.72      0.71        32
# weighted avg       0.74      0.72      0.71        32
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.65      0.81      0.72        16
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
#
# 🎯 PCA n_components=14
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.62      0.50      0.55        16
#            1       0.58      0.69      0.63        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.62      0.81      0.70        16
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.66      0.65        32
# weighted avg       0.67      0.66      0.65        32
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46        16
#            1       0.55      0.75      0.63        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.70      0.44      0.54        16
#            1       0.59      0.81      0.68        16
#
#     accuracy                           0.62        32
#    macro avg       0.65      0.62      0.61        32
# weighted avg       0.65      0.62      0.61        32
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69        16
#            1       0.69      0.69      0.69        16
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67        16
#            1       0.67      0.88      0.76        16
#
#     accuracy                           0.72        32
#    macro avg       0.74      0.72      0.71        32
# weighted avg       0.74      0.72      0.71        32
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 7, 'iterations': 200, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.89      0.50      0.64        16
#            1       0.65      0.94      0.77        16
#
#     accuracy                           0.72        32
#    macro avg       0.77      0.72      0.70        32
# weighted avg       0.77      0.72      0.70        32
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.62      0.81      0.70        16
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.66      0.65        32
# weighted avg       0.67      0.66      0.65        32
#
#
# 🎯 PCA n_components=16
#
# Tuning Logistic Regression (PCA)...
#
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.58      0.44      0.50        16
#            1       0.55      0.69      0.61        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.73      0.50      0.59        16
#            1       0.62      0.81      0.70        16
#
#     accuracy                           0.66        32
#    macro avg       0.67      0.66      0.65        32
# weighted avg       0.67      0.66      0.65        32
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.60      0.38      0.46        16
#            1       0.55      0.75      0.63        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.55        32
# weighted avg       0.57      0.56      0.55        32
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.65      0.81      0.72        16
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71        16
#            1       0.70      0.88      0.78        16
#
#     accuracy                           0.75        32
#    macro avg       0.77      0.75      0.75        32
# weighted avg       0.77      0.75      0.75        32
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.82      0.56      0.67        16
#            1       0.67      0.88      0.76        16
#
#     accuracy                           0.72        32
#    macro avg       0.74      0.72      0.71        32
# weighted avg       0.74      0.72      0.71        32
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.80      0.50      0.62        16
#            1       0.64      0.88      0.74        16
#
#     accuracy                           0.69        32
#    macro avg       0.72      0.69      0.68        32
# weighted avg       0.72      0.69      0.68        32
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.88      0.44      0.58        16
#            1       0.62      0.94      0.75        16
#
#     accuracy                           0.69        32
#    macro avg       0.75      0.69      0.67        32
# weighted avg       0.75      0.69      0.67        32
#
#
# 🎯 PCA n_components=34
#
# Tuning Logistic Regression (PCA)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Logistic Regression (PCA + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.70      0.44      0.54        16
#            1       0.59      0.81      0.68        16
#
#     accuracy                           0.62        32
#    macro avg       0.65      0.62      0.61        32
# weighted avg       0.65      0.62      0.61        32
#
#
# Tuning SVM (PCA)...
#
# ==== SVM (PCA + Tuned) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.70      0.44      0.54        16
#            1       0.59      0.81      0.68        16
#
#     accuracy                           0.62        32
#    macro avg       0.65      0.62      0.61        32
# weighted avg       0.65      0.62      0.61        32
#
#
# Tuning KNN (PCA)...
#
# ==== KNN (PCA + Tuned) ====
# Best Params: {'n_neighbors': 3}
#               precision    recall  f1-score   support
#
#            0       0.64      0.44      0.52        16
#            1       0.57      0.75      0.65        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.58        32
# weighted avg       0.60      0.59      0.58        32
#
#
# Tuning Random Forest (PCA)...
#
# ==== Random Forest (PCA + Tuned) ====
# Best Params: {'max_depth': None, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.83      0.62      0.71        16
#            1       0.70      0.88      0.78        16
#
#     accuracy                           0.75        32
#    macro avg       0.77      0.75      0.75        32
# weighted avg       0.77      0.75      0.75        32
#
#
# Tuning AdaBoost (PCA)...
#
# ==== AdaBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.75      0.56      0.64        16
#            1       0.65      0.81      0.72        16
#
#     accuracy                           0.69        32
#    macro avg       0.70      0.69      0.68        32
# weighted avg       0.70      0.69      0.68        32
#
#
# Tuning Gradient Boosting (PCA)...
#
# ==== Gradient Boosting (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.71      0.62      0.67        16
#            1       0.67      0.75      0.71        16
#
#     accuracy                           0.69        32
#    macro avg       0.69      0.69      0.69        32
# weighted avg       0.69      0.69      0.69        32
#
#
# Tuning CatBoost (PCA)...
#
# ==== CatBoost (PCA + Tuned) ====
# Best Params: {'depth': 5, 'iterations': 100, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.91      0.62      0.74        16
#            1       0.71      0.94      0.81        16
#
#     accuracy                           0.78        32
#    macro avg       0.81      0.78      0.78        32
# weighted avg       0.81      0.78      0.78        32
#
#
# Tuning XGBoost (PCA)...
#
# ==== XGBoost (PCA + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.85      0.69      0.76        16
#            1       0.74      0.88      0.80        16
#
#     accuracy                           0.78        32
#    macro avg       0.79      0.78      0.78        32
# weighted avg       0.79      0.78      0.78        32
#
#
# ✅ Hasil Hyperparameter Tuning PCA:
#  n_components               Model                                                  Best Params  Accuracy  Precision  Recall  F1-Score
#            10       Random Forest                       {'max_depth': 10, 'n_estimators': 200}   0.78125   0.714286  0.9375  0.810811
#            10            CatBoost       {'depth': 7, 'iterations': 200, 'learning_rate': 0.03}   0.71875   0.652174  0.9375  0.769231
#            10             XGBoost  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}   0.68750   0.636364  0.8750  0.736842
#            10                 KNN                                           {'n_neighbors': 5}   0.68750   0.650000  0.8125  0.722222
#            10            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}   0.68750   0.666667  0.7500  0.705882
#            10                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.65625   0.619048  0.8125  0.702703
#            10   Gradient Boosting  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}   0.65625   0.631579  0.7500  0.685714
#            10 Logistic Regression                                                    {'C': 10}   0.56250   0.555556  0.6250  0.588235
#            11       Random Forest                     {'max_depth': None, 'n_estimators': 200}   0.78125   0.714286  0.9375  0.810811
#            11            CatBoost        {'depth': 7, 'iterations': 100, 'learning_rate': 0.1}   0.71875   0.666667  0.8750  0.756757
#            11             XGBoost  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}   0.71875   0.684211  0.8125  0.742857
#            11   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}   0.68750   0.650000  0.8125  0.722222
#            11                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.65625   0.619048  0.8125  0.702703
#            11                 KNN                                           {'n_neighbors': 3}   0.56250   0.545455  0.7500  0.631579
#            11 Logistic Regression                                                     {'C': 1}   0.59375   0.578947  0.6875  0.628571
#            11            AdaBoost                  {'learning_rate': 0.5, 'n_estimators': 200}   0.59375   0.578947  0.6875  0.628571
#            12   Gradient Boosting   {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}   0.75000   0.681818  0.9375  0.789474
#            12       Random Forest                     {'max_depth': None, 'n_estimators': 100}   0.71875   0.652174  0.9375  0.769231
#            12            CatBoost        {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}   0.71875   0.666667  0.8750  0.756757
#            12             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}   0.68750   0.650000  0.8125  0.722222
#            12                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.62500   0.600000  0.7500  0.666667
#            12                 KNN                                           {'n_neighbors': 3}   0.56250   0.545455  0.7500  0.631579
#            12 Logistic Regression                                                     {'C': 1}   0.59375   0.578947  0.6875  0.628571
#            12            AdaBoost                   {'learning_rate': 1.0, 'n_estimators': 50}   0.59375   0.588235  0.6250  0.606061
#            14            CatBoost       {'depth': 7, 'iterations': 200, 'learning_rate': 0.03}   0.71875   0.652174  0.9375  0.769231
#            14   Gradient Boosting   {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}   0.71875   0.666667  0.8750  0.756757
#            14                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.65625   0.619048  0.8125  0.702703
#            14             XGBoost  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 200}   0.65625   0.619048  0.8125  0.702703
#            14            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 100}   0.68750   0.687500  0.6875  0.687500
#            14       Random Forest                     {'max_depth': None, 'n_estimators': 100}   0.62500   0.590909  0.8125  0.684211
#            14                 KNN                                           {'n_neighbors': 3}   0.56250   0.545455  0.7500  0.631579
#            14 Logistic Regression                                                    {'C': 10}   0.59375   0.578947  0.6875  0.628571
#            16            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}   0.75000   0.700000  0.8750  0.777778
#            16   Gradient Boosting  {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 100}   0.71875   0.666667  0.8750  0.756757
#            16             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 100}   0.68750   0.625000  0.9375  0.750000
#            16            CatBoost        {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}   0.68750   0.636364  0.8750  0.736842
#            16       Random Forest                      {'max_depth': None, 'n_estimators': 50}   0.68750   0.650000  0.8125  0.722222
#            16                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.65625   0.619048  0.8125  0.702703
#            16                 KNN                                           {'n_neighbors': 3}   0.56250   0.545455  0.7500  0.631579
#            16 Logistic Regression                                                    {'C': 10}   0.56250   0.550000  0.6875  0.611111
#            34            CatBoost       {'depth': 5, 'iterations': 100, 'learning_rate': 0.03}   0.78125   0.714286  0.9375  0.810811
#            34             XGBoost {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}   0.78125   0.736842  0.8750  0.800000
#            34       Random Forest                     {'max_depth': None, 'n_estimators': 200}   0.75000   0.700000  0.8750  0.777778
#            34            AdaBoost                   {'learning_rate': 1.0, 'n_estimators': 50}   0.68750   0.650000  0.8125  0.722222
#            34   Gradient Boosting {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}   0.68750   0.666667  0.7500  0.705882
#            34 Logistic Regression                                                    {'C': 10}   0.62500   0.590909  0.8125  0.684211
#            34                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.62500   0.590909  0.8125  0.684211
#            34                 KNN                                           {'n_neighbors': 3}   0.59375   0.571429  0.7500  0.648649

# %% [markdown]
# Copy to Clipboard

# %%
n_target = 34

# Filter berdasarkan n_components
df_filtered = df_results_pca_tuned_sorted[df_results_pca_tuned_sorted["n_components"] == n_target]

# Drop kolom yang tidak ingin disalin
df_to_copy = df_filtered.drop(columns=["n_components"])

# Tampilkan ke terminal
print(f"\n📋 Hasil untuk n_components = {n_target}:")
print(df_to_copy.to_string(index=False))

# Salin ke clipboard agar bisa langsung ditempel ke Excel
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
# 📋 Hasil untuk n_components = 34:
#               Model                                                  Best Params  Accuracy  Precision  Recall  F1-Score
#            CatBoost       {'depth': 5, 'iterations': 100, 'learning_rate': 0.03}   0.78125   0.714286  0.9375  0.810811
#             XGBoost {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}   0.78125   0.736842  0.8750  0.800000
#       Random Forest                     {'max_depth': None, 'n_estimators': 200}   0.75000   0.700000  0.8750  0.777778
#            AdaBoost                   {'learning_rate': 1.0, 'n_estimators': 50}   0.68750   0.650000  0.8125  0.722222
#   Gradient Boosting {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}   0.68750   0.666667  0.7500  0.705882
# Logistic Regression                                                    {'C': 10}   0.62500   0.590909  0.8125  0.684211
#                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.62500   0.590909  0.8125  0.684211
#                 KNN                                           {'n_neighbors': 3}   0.59375   0.571429  0.7500  0.648649

# %% [markdown]
# ##### Hyperparameter Tuning After t-SNE

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import classification_report, accuracy_score, f1_score, precision_score, recall_score
import pandas as pd

# 1️⃣ Konfigurasi kombinasi
output_dims = [10, 11, 12, 14, 16, 34]
perplexity = 5

# 3️⃣ Simpan hasil tuning semua output_dim
results_tsne_tuned = []

for out_dim in output_dims:
    print(f"\n🎯 Parametric t-SNE output_dim={out_dim}, perplexity={perplexity}")
    
    # Buat dan fit Parametric t-SNE
    ptSNE = Parametric_tSNE(num_inputs=X_scaled.shape[1], num_outputs=out_dim, perplexities=perplexity, seed=42)
    ptSNE.fit(X_train_raw)

    X_train_tsne = ptSNE.transform(X_train_raw)
    X_test_tsne = ptSNE.transform(X_test_raw)

    for name, model in models.items():
        if name == "SVM":
            print("\n▶️ Skip GridSearch for SVM. Use best param from PCA!")
            best_params_svm_pca = {
                "C": 10,
                "kernel": "rbf"
            }
            svm_model = SVC(**best_params_svm_pca)
            svm_model.fit(X_train_tsne, y_train)
            y_pred = svm_model.predict(X_test_tsne)

            acc = accuracy_score(y_test, y_pred)
            prec = precision_score(y_test, y_pred)
            rec = recall_score(y_test, y_pred)
            f1 = f1_score(y_test, y_pred)

            results_tsne_tuned.append({
                "Output Dim": out_dim,
                "Perplexity": perplexity,
                "Model": name,
                "Best Params": best_params_svm_pca,
                "Accuracy": acc,
                "Precision": prec,
                "Recall": rec,
                "F1-Score": f1
            })

            print(f"\n==== {name} (Parametric t-SNE + Best Param PCA) ====")
            print("Best Params:", best_params_svm_pca)
            print(classification_report(y_test, y_pred))
            continue

        print(f"\nTuning {name} (Parametric t-SNE)...")
        grid = GridSearchCV(
            model,
            param_grids[name],
            cv=StratifiedKFold(n_splits=5),
            scoring='f1',
            n_jobs=-1
        )
        grid.fit(X_train_tsne, y_train)

        best_model = grid.best_estimator_
        y_pred = best_model.predict(X_test_tsne)

        acc = accuracy_score(y_test, y_pred)
        prec = precision_score(y_test, y_pred)
        rec = recall_score(y_test, y_pred)
        f1 = f1_score(y_test, y_pred)

        results_tsne_tuned.append({
            "Output Dim": out_dim,
            "Perplexity": perplexity,
            "Model": name,
            "Best Params": grid.best_params_,
            "Accuracy": acc,
            "Precision": prec,
            "Recall": rec,
            "F1-Score": f1
        })

        print(f"\n==== {name} (Parametric t-SNE + Tuned) ====")
        print("Best Params:", grid.best_params_)
        print(classification_report(y_test, y_pred))

# 4️⃣ Simpan hasil tuning ke DataFrame
df_results_tsne_tuned = pd.DataFrame(results_tsne_tuned)
df_results_tsne_tuned_sorted = df_results_tsne_tuned.sort_values(by=["Output Dim", "F1-Score"], ascending=[True, False])

print("\n✅ Hasil Hyperparameter Tuning Parametric t-SNE:")
print(df_results_tsne_tuned_sorted.to_string(index=False))

# 5️⃣ Simpan ke file CSV (opsional)
# df_results_tsne_tuned_sorted.to_csv("parametric_tsne_tuned_results.csv", index=False)
# Out:
# 🎯 Parametric t-SNE output_dim=10, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 5}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.50      0.62      0.56        16
#            1       0.50      0.38      0.43        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        16
#            1       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 3, 'iterations': 100, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53        16
#            1       0.50      0.44      0.47        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# 🎯 Parametric t-SNE output_dim=11, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 9}
#               precision    recall  f1-score   support
#
#            0       0.50      0.56      0.53        16
#            1       0.50      0.44      0.47        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        16
#            1       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 3, 'iterations': 200, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.50      0.62      0.56        16
#            1       0.50      0.38      0.43        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.56      0.56      0.56        16
#            1       0.56      0.56      0.56        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# 🎯 Parametric t-SNE output_dim=12, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 9}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning Random Forest (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': 5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.60      0.75      0.67        16
#            1       0.67      0.50      0.57        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.55      0.69      0.61        16
#            1       0.58      0.44      0.50        16
#
#     accuracy                           0.56        32
#    macro avg       0.57      0.56      0.56        32
# weighted avg       0.57      0.56      0.56        32
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.64      0.56      0.60        16
#            1       0.61      0.69      0.65        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 5, 'iterations': 200, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        16
#            1       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.61        16
#            1       0.60      0.56      0.58        16
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
#
# 🎯 Parametric t-SNE output_dim=14, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 9}
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59        16
#            1       0.57      0.50      0.53        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': 10, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        16
#            1       0.50      0.50      0.50        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.56      0.62      0.59        16
#            1       0.57      0.50      0.53        16
#
#     accuracy                           0.56        32
#    macro avg       0.56      0.56      0.56        32
# weighted avg       0.56      0.56      0.56        32
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        16
#            1       0.50      0.50      0.50        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.53      0.56      0.55        16
#            1       0.53      0.50      0.52        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.53      0.56      0.55        16
#            1       0.53      0.50      0.52        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# 🎯 Parametric t-SNE output_dim=16, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 0.01}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 9}
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        16
#            1       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning Random Forest (Parametric t-SNE)...
#
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.58      0.69      0.63        16
#            1       0.62      0.50      0.55        16
#
#     accuracy                           0.59        32
#    macro avg       0.60      0.59      0.59        32
# weighted avg       0.60      0.59      0.59        32
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.59      0.62      0.61        16
#            1       0.60      0.56      0.58        16
#
#     accuracy                           0.59        32
#    macro avg       0.59      0.59      0.59        32
# weighted avg       0.59      0.59      0.59        32
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 3, 'iterations': 100, 'learning_rate': 0.03}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.64      0.56      0.60        16
#            1       0.61      0.69      0.65        16
#
#     accuracy                           0.62        32
#    macro avg       0.63      0.62      0.62        32
# weighted avg       0.63      0.62      0.62        32
#
#
# 🎯 Parametric t-SNE output_dim=34, perplexity=5
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\keras\src\layers\core\dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
#
# Tuning Logistic Regression (Parametric t-SNE)...
#
# ==== Logistic Regression (Parametric t-SNE + Tuned) ====
# Best Params: {'C': 10}
#               precision    recall  f1-score   support
#
#            0       0.53      0.62      0.57        16
#            1       0.54      0.44      0.48        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# ▶️ Skip GridSearch for SVM. Use best param from PCA!
#
# ==== SVM (Parametric t-SNE + Best Param PCA) ====
# Best Params: {'C': 10, 'kernel': 'rbf'}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning KNN (Parametric t-SNE)...
#
# ==== KNN (Parametric t-SNE + Tuned) ====
# Best Params: {'n_neighbors': 7}
#               precision    recall  f1-score   support
#
#            0       0.47      0.56      0.51        16
#            1       0.46      0.38      0.41        16
#
#     accuracy                           0.47        32
#    macro avg       0.47      0.47      0.46        32
# weighted avg       0.47      0.47      0.46        32
#
#
# Tuning Random Forest (Parametric t-SNE)...
# c:\Users\afilz\works\machine-learning\ta\venv310\lib\site-packages\sklearn\linear_model\_sag.py:348: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ==== Random Forest (Parametric t-SNE + Tuned) ====
# Best Params: {'max_depth': 5, 'n_estimators': 100}
#               precision    recall  f1-score   support
#
#            0       0.52      0.69      0.59        16
#            1       0.55      0.38      0.44        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.52        32
# weighted avg       0.53      0.53      0.52        32
#
#
# Tuning AdaBoost (Parametric t-SNE)...
#
# ==== AdaBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 1.0, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.50      0.62      0.56        16
#            1       0.50      0.38      0.43        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.49        32
# weighted avg       0.50      0.50      0.49        32
#
#
# Tuning Gradient Boosting (Parametric t-SNE)...
#
# ==== Gradient Boosting (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}
#               precision    recall  f1-score   support
#
#            0       0.53      0.56      0.55        16
#            1       0.53      0.50      0.52        16
#
#     accuracy                           0.53        32
#    macro avg       0.53      0.53      0.53        32
# weighted avg       0.53      0.53      0.53        32
#
#
# Tuning CatBoost (Parametric t-SNE)...
#
# ==== CatBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'depth': 3, 'iterations': 200, 'learning_rate': 0.1}
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50        16
#            1       0.50      0.50      0.50        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# Tuning XGBoost (Parametric t-SNE)...
#
# ==== XGBoost (Parametric t-SNE + Tuned) ====
# Best Params: {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}
#               precision    recall  f1-score   support
#
#            0       0.50      0.44      0.47        16
#            1       0.50      0.56      0.53        16
#
#     accuracy                           0.50        32
#    macro avg       0.50      0.50      0.50        32
# weighted avg       0.50      0.50      0.50        32
#
#
# ✅ Hasil Hyperparameter Tuning Parametric t-SNE:
#  Output Dim  Perplexity               Model                                                  Best Params  Accuracy  Precision  Recall  F1-Score
#          10           5   Gradient Boosting  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}   0.59375   0.615385  0.5000  0.551724
#          10           5 Logistic Regression                                                  {'C': 0.01}   0.53125   0.538462  0.4375  0.482759
#          10           5                 KNN                                           {'n_neighbors': 5}   0.53125   0.538462  0.4375  0.482759
#          10           5             XGBoost {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}   0.50000   0.500000  0.4375  0.466667
#          10           5                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#          10           5            AdaBoost                   {'learning_rate': 0.5, 'n_estimators': 50}   0.53125   0.545455  0.3750  0.444444
#          10           5            CatBoost       {'depth': 3, 'iterations': 100, 'learning_rate': 0.03}   0.53125   0.545455  0.3750  0.444444
#          10           5       Random Forest                         {'max_depth': 5, 'n_estimators': 50}   0.50000   0.500000  0.3750  0.428571
#          11           5             XGBoost  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 200}   0.56250   0.562500  0.5625  0.562500
#          11           5   Gradient Boosting  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}   0.59375   0.615385  0.5000  0.551724
#          11           5 Logistic Regression                                                    {'C': 10}   0.53125   0.538462  0.4375  0.482759
#          11           5                 KNN                                           {'n_neighbors': 9}   0.50000   0.500000  0.4375  0.466667
#          11           5                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#          11           5       Random Forest                         {'max_depth': 5, 'n_estimators': 50}   0.53125   0.545455  0.3750  0.444444
#          11           5            AdaBoost                   {'learning_rate': 0.5, 'n_estimators': 50}   0.53125   0.545455  0.3750  0.444444
#          11           5            CatBoost       {'depth': 3, 'iterations': 200, 'learning_rate': 0.03}   0.50000   0.500000  0.3750  0.428571
#          12           5   Gradient Boosting   {'learning_rate': 0.1, 'max_depth': 3, 'n_estimators': 50}   0.62500   0.611111  0.6875  0.647059
#          12           5             XGBoost {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 200}   0.59375   0.600000  0.5625  0.580645
#          12           5       Random Forest                        {'max_depth': 5, 'n_estimators': 200}   0.62500   0.666667  0.5000  0.571429
#          12           5            CatBoost       {'depth': 5, 'iterations': 200, 'learning_rate': 0.03}   0.59375   0.615385  0.5000  0.551724
#          12           5            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 100}   0.56250   0.583333  0.4375  0.500000
#          12           5 Logistic Regression                                                    {'C': 10}   0.53125   0.538462  0.4375  0.482759
#          12           5                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#          12           5                 KNN                                           {'n_neighbors': 9}   0.53125   0.545455  0.3750  0.444444
#          14           5                 KNN                                           {'n_neighbors': 9}   0.56250   0.571429  0.5000  0.533333
#          14           5            AdaBoost                   {'learning_rate': 1.0, 'n_estimators': 50}   0.56250   0.571429  0.5000  0.533333
#          14           5            CatBoost        {'depth': 5, 'iterations': 200, 'learning_rate': 0.1}   0.53125   0.533333  0.5000  0.516129
#          14           5             XGBoost {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 100}   0.53125   0.533333  0.5000  0.516129
#          14           5       Random Forest                        {'max_depth': 10, 'n_estimators': 50}   0.50000   0.500000  0.5000  0.500000
#          14           5   Gradient Boosting   {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 50}   0.50000   0.500000  0.5000  0.500000
#          14           5 Logistic Regression                                                  {'C': 0.01}   0.53125   0.538462  0.4375  0.482759
#          14           5                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#          16           5             XGBoost  {'learning_rate': 0.1, 'max_depth': 5, 'n_estimators': 100}   0.62500   0.611111  0.6875  0.647059
#          16           5   Gradient Boosting  {'learning_rate': 0.05, 'max_depth': 3, 'n_estimators': 50}   0.59375   0.600000  0.5625  0.580645
#          16           5                 KNN                                           {'n_neighbors': 9}   0.59375   0.615385  0.5000  0.551724
#          16           5       Random Forest                        {'max_depth': 5, 'n_estimators': 100}   0.59375   0.615385  0.5000  0.551724
#          16           5 Logistic Regression                                                  {'C': 0.01}   0.53125   0.538462  0.4375  0.482759
#          16           5                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#          16           5            AdaBoost                   {'learning_rate': 0.5, 'n_estimators': 50}   0.53125   0.545455  0.3750  0.444444
#          16           5            CatBoost       {'depth': 3, 'iterations': 100, 'learning_rate': 0.03}   0.53125   0.545455  0.3750  0.444444
#          34           5             XGBoost  {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}   0.50000   0.500000  0.5625  0.529412
#          34           5   Gradient Boosting  {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}   0.53125   0.533333  0.5000  0.516129
#          34           5            CatBoost        {'depth': 3, 'iterations': 200, 'learning_rate': 0.1}   0.50000   0.500000  0.5000  0.500000
#          34           5 Logistic Regression                                                    {'C': 10}   0.53125   0.538462  0.4375  0.482759
#          34           5                 SVM                                   {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#          34           5       Random Forest                        {'max_depth': 5, 'n_estimators': 100}   0.53125   0.545455  0.3750  0.444444
#          34           5            AdaBoost                  {'learning_rate': 1.0, 'n_estimators': 200}   0.50000   0.500000  0.3750  0.428571
#          34           5                 KNN                                           {'n_neighbors': 7}   0.46875   0.461538  0.3750  0.413793

# %% [markdown]
# Copy to clipboard

# %%
out_dim = 34
df_filtered = df_results_tsne_tuned_sorted[df_results_tsne_tuned_sorted["Output Dim"] == out_dim]

# Drop kolom yang tidak perlu disalin
df_to_copy = df_filtered.drop(columns=["Output Dim", "Perplexity"])

# Tampilkan ke terminal
print(df_to_copy.to_string(index=False))

# Salin ke clipboard tanpa kolom tambahan
df_to_copy.to_clipboard(index=False, sep='\t')
# Out:
#               Model                                                 Best Params  Accuracy  Precision  Recall  F1-Score
#             XGBoost {'learning_rate': 0.1, 'max_depth': 7, 'n_estimators': 200}   0.50000   0.500000  0.5625  0.529412
#   Gradient Boosting {'learning_rate': 0.05, 'max_depth': 5, 'n_estimators': 50}   0.53125   0.533333  0.5000  0.516129
#            CatBoost       {'depth': 3, 'iterations': 200, 'learning_rate': 0.1}   0.50000   0.500000  0.5000  0.500000
# Logistic Regression                                                   {'C': 10}   0.53125   0.538462  0.4375  0.482759
#                 SVM                                  {'C': 10, 'kernel': 'rbf'}   0.53125   0.545455  0.3750  0.444444
#       Random Forest                       {'max_depth': 5, 'n_estimators': 100}   0.53125   0.545455  0.3750  0.444444
#            AdaBoost                 {'learning_rate': 1.0, 'n_estimators': 200}   0.50000   0.500000  0.3750  0.428571
#                 KNN                                          {'n_neighbors': 7}   0.46875   0.461538  0.3750  0.413793

# %% [markdown]
# Export to CSV

# %%
# (opsional) simpan ke file CSV
df_results_tsne_tuned.to_csv(f"{lowercase_dataset}_tsne.csv", index=False)

# %% [markdown]
# ##### Cross Validation for Random Forest after PCA (best model)
